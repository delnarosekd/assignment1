# %% [markdown]
# # 1. Read the dataset to python environment.

# %%
import pandas as pd
data=pd.read_excel(r"C:\Users\DELNA ROSE\Downloads\iris (2).xls")
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2. Display the columns in the dataset.

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset.

# %%
import pandas as pd
avg_data=pd.DataFrame(data)
mean=avg_data.mean(axis=0)
print(mean)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
null_values=data.isna()
null_values
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset.

# %% [markdown]
# # SCATTER PLOT

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.scatterplot(x=data['SW'],y=data['PW'],data=data,hue=data['Classification'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # PAIR PLOT

# %%
import seaborn as sns
data_1=data[['SL','PL','SW','PW']]
sns.pairplot(data_1)

# %% [markdown]
# # BOXPLOT

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.boxplot(x=data['Classification'],y=data['SW'],data=data)
plt.title('Effect of SEPAL on classification of Flowers')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
